# %% [markdown]
# # Automatización de separación de PDF por radicado y empresa
#
# Este notebook automatiza la separación de un PDF masivo de notificaciones, generando un archivo PDF por cada correo, usando el código de radicado y el nombre de la empresa en el nombre del archivo.

# %% [markdown]
# ## 1. Instalación de librerías necesarias
#
# Esta celda instala las librerías requeridas para manipular PDFs y extraer texto.

# %%
# Instala PyPDF2 y pdfplumber si no están instalados
# !pip install PyPDF2 pdfplumber

# %% [markdown]
# ## 2. Importación de librerías y definición de funciones
#
# Esta celda importa las librerías necesarias y define la función para separar el PDF según el radicado y empresa.

# %%
import os
import re
import pdfplumber
from PyPDF2 import PdfWriter

# Función para extraer radicado y Nit/CC de una página
def extraer_info(texto):
    radicado_match = re.search(r'(AEI/\d{3}\. \d{5})', texto)
    radicado = radicado_match.group(1) if radicado_match else None
    if radicado:
        radicado = radicado.replace('/', '-')
    nit_match = re.search(r'(Nit / CC \d+)', texto)
    nit = nit_match.group(1).replace(' ', '_') if nit_match else None
    return radicado, nit

# Función principal para separar el PDF por bloques de páginas
def separar_pdf_por_radicado(pdf_path, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    with pdfplumber.open(pdf_path) as pdf:
        bloques = []
        bloque_actual = {'clave': None, 'paginas': []}
        for i, page in enumerate(pdf.pages):
            texto = page.extract_text() or ''
            radicado, nit = extraer_info(texto)
            clave = f'{radicado}_{nit}' if radicado and nit else None
            # Si encontramos un nuevo bloque (nuevo radicado/nit)
            if clave and (bloque_actual['clave'] != clave):
                if bloque_actual['clave'] and bloque_actual['paginas']:
                    bloques.append(bloque_actual)
                bloque_actual = {'clave': clave, 'paginas': [i]}
            else:
                bloque_actual['paginas'].append(i)
        # Agregar el último bloque
        if bloque_actual['clave'] and bloque_actual['paginas']:
            bloques.append(bloque_actual)

    from PyPDF2 import PdfReader
    reader = PdfReader(pdf_path)
    for bloque in bloques:
        writer = PdfWriter()
        for idx in bloque['paginas']:
            writer.add_page(reader.pages[idx])
        nombre_pdf = f"{bloque['clave']}.pdf".replace('/', '-')
        ruta_pdf = os.path.join(output_dir, nombre_pdf)
        with open(ruta_pdf, 'wb') as f_out:
            writer.write(f_out)
        print(f"Se guardó: {ruta_pdf} con {len(bloque['paginas'])} páginas")

# %% [markdown]
# ## 3. Ejecución de la automatización
#
# Esta celda ejecuta la función principal para separar el PDF masivo y guardar los archivos individuales en la carpeta de resultados.

# %%
# Ruta del PDF masivo y carpeta de salida
pdf_path = r'C:\Users\osmarrincon\Downloads\pdf\NOTIFICACION  UGPP 1.pdf'
output_dir = r'C:\Users\osmarrincon\Downloads\pdf\Resultado'

# Ejecutar la separación
separar_pdf_por_radicado(pdf_path, output_dir)
# Out:
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37889_Nit_-_CC_9008063579.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37888_Nit_-_CC_9008063579.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37887_Nit_-_CC_1123038700.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37886_Nit_-_CC_1123038700.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37885_Nit_-_CC_1118650907.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37884_Nit_-_CC_1118650907.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37883_Nit_-_CC_1118650442.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37882_Nit_-_CC_1118648151.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37881_Nit_-_CC_1118648151.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37880_Nit_-_CC_1118576935.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37879_Nit_-_CC_1118576935.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37878_Nit_-_CC_1118569403.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37877_Nit_-_CC_1118569403.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37876_Nit_-_CC_1118568364.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37875_Nit_-_CC_1118568364.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37874_Nit_-_CC_1118566796.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37873_Nit_-_CC_1118566796.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37872_Nit_-_CC_1118564192.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37871_Nit_-_CC_1118564192.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37870_Nit_-_CC_1118561980.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37869_Nit_-_CC_1118561980.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37868_Nit_-_CC_1118561659.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37867_Nit_-_CC_1118561659.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37866_Nit_-_CC_1118557649.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37865_Nit_-_CC_1118557649.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37864_Nit_-_CC_1118555761.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37863_Nit_-_CC_1118555761.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37862_Nit_-_CC_1118546675.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37861_Nit_-_CC_1118546675.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37860_Nit_-_CC_1118543176.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37859_Nit_-_CC_1118541753.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37858_Nit_-_CC_1118541753.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37857_Nit_-_CC_1118539173.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37856_Nit_-_CC_1118539173.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37855_Nit_-_CC_1118537814.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37854_Nit_-_CC_1118537814.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37853_Nit_-_CC_1118536931.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37852_Nit_-_CC_1118536931.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37851_Nit_-_CC_1118532069.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37850_Nit_-_CC_1118532069.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37849_Nit_-_CC_1118531879.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37848_Nit_-_CC_1118531879.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37847_Nit_-_CC_1118530235.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37846_Nit_-_CC_1118530235.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37865_Nit_-_CC_1118557649.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37864_Nit_-_CC_1118555761.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37863_Nit_-_CC_1118555761.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37862_Nit_-_CC_1118546675.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37861_Nit_-_CC_1118546675.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37860_Nit_-_CC_1118543176.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37859_Nit_-_CC_1118541753.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37858_Nit_-_CC_1118541753.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37857_Nit_-_CC_1118539173.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37856_Nit_-_CC_1118539173.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37855_Nit_-_CC_1118537814.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37854_Nit_-_CC_1118537814.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37853_Nit_-_CC_1118536931.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37852_Nit_-_CC_1118536931.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37851_Nit_-_CC_1118532069.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37850_Nit_-_CC_1118532069.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37849_Nit_-_CC_1118531879.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37848_Nit_-_CC_1118531879.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37847_Nit_-_CC_1118530235.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37846_Nit_-_CC_1118530235.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37845_Nit_-_CC_1118530092.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37844_Nit_-_CC_1118530092.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37843_Nit_-_CC_1118529869.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37842_Nit_-_CC_1118529869.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37841_Nit_-_CC_1118529600.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37840_Nit_-_CC_1118529600.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37839_Nit_-_CC_1118203523.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37838_Nit_-_CC_1118203523.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37837_Nit_-_CC_1118202615.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37836_Nit_-_CC_1118202615.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37835_Nit_-_CC_1118125804.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37834_Nit_-_CC_1118125804.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37833_Nit_-_CC_1116993088.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37832_Nit_-_CC_1116993088.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37831_Nit_-_CC_1116862372.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37830_Nit_-_CC_1116862372.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37829_Nit_-_CC_1116615433.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37828_Nit_-_CC_1116615433.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37827_Nit_-_CC_1116553219.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37826_Nit_-_CC_1116553219.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37825_Nit_-_CC_1116547533.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37824_Nit_-_CC_1116547490.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37845_Nit_-_CC_1118530092.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37844_Nit_-_CC_1118530092.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37843_Nit_-_CC_1118529869.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37842_Nit_-_CC_1118529869.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37841_Nit_-_CC_1118529600.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37840_Nit_-_CC_1118529600.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37839_Nit_-_CC_1118203523.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37838_Nit_-_CC_1118203523.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37837_Nit_-_CC_1118202615.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37836_Nit_-_CC_1118202615.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37835_Nit_-_CC_1118125804.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37834_Nit_-_CC_1118125804.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37833_Nit_-_CC_1116993088.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37832_Nit_-_CC_1116993088.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37831_Nit_-_CC_1116862372.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37830_Nit_-_CC_1116862372.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37829_Nit_-_CC_1116615433.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37828_Nit_-_CC_1116615433.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37827_Nit_-_CC_1116553219.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37826_Nit_-_CC_1116553219.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37825_Nit_-_CC_1116547533.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37824_Nit_-_CC_1116547490.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37823_Nit_-_CC_1116547490.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37822_Nit_-_CC_1116545732.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37821_Nit_-_CC_1116545732.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37820_Nit_-_CC_1116543936.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37819_Nit_-_CC_1116543936.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37818_Nit_-_CC_1116042814.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37817_Nit_-_CC_1116042814.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37816_Nit_-_CC_1115917831.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37815_Nit_-_CC_1115917831.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37814_Nit_-_CC_1115914584.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37813_Nit_-_CC_1115914584.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37812_Nit_-_CC_1115913232.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37823_Nit_-_CC_1116547490.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37822_Nit_-_CC_1116545732.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37821_Nit_-_CC_1116545732.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37820_Nit_-_CC_1116543936.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37819_Nit_-_CC_1116543936.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37818_Nit_-_CC_1116042814.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37817_Nit_-_CC_1116042814.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37816_Nit_-_CC_1115917831.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37815_Nit_-_CC_1115917831.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37814_Nit_-_CC_1115914584.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37813_Nit_-_CC_1115914584.pdf con 3 páginas
# Se guardó: C:\Users\osmarrincon\Downloads\pdf\Resultado\AEI-120. 37812_Nit_-_CC_1115913232.pdf con 3 páginas
