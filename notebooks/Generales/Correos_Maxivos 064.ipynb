# %%
# Módulos necesarios
import os  # Trabajar con rutas del sistema
import pandas as pd  # Trabajar con DataFrames
import datetime  # Manejo de fechas
from pathlib import Path  # Manejo de rutas
import smtplib  # Envío de correos
from email.mime.text import MIMEText  # Crear correos con texto
from email.mime.multipart import MIMEMultipart  # Correos con múltiples partes
from PyPDF2 import PdfReader  # Leer archivos PDF
import re  # Para validación de correos electrónicos

# %% [markdown]
# # 1. Rutas

# %%
Asunto = "NOTIFICACION MOVILIDAD AL REGIMEN SUBSIDIADO EN Septiembre 2025"
Archivo_Name = "Movilidad064_Septiembre_2025"
Fecha = "VIERNES, 10 de Octubre de 2025"
Fecha_Documento = "Yopal, 10 de octubre 2025"

# %%
# Rutas
R_Automatico_S1 = r"\\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\MOVILIDAD SEPTIEMBRE"
R_Municipios = r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Proyecto INOVA\Colab_Notebooks\dashboard\Base de datos\Codigo DANE\Departamentos.txt"
#R_MS_SIE = r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Escritorio\Yesid Rincón Z\informes\2025\CTO135.2025 Informe  #3\ACTIVIDAD 19\19.1. Bases de datos notificaciones telefonicas\Validado SIE.xlsx"
R_MS_SIE = r"C:\Users\osmarrincon\OneDrive - uniminuto.edu\Capresoca\AlmostClear\SIE\Aseguramiento\ms_sie\Reporte_Validación Archivos Maestro_2025_10_26.csv"
R_Sisben = r"C:\Users\osmarrincon\OneDrive - uniminuto.edu\Capresoca\AlmostClear\SISBEN\2025\08_Agosto\DNP-SISBEN-CO-0000080193.xlsx"
Logo_Capresoca = r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\capre.png"
R_Red_Servicios = r"C:\Users\osmarrincon\OneDrive - uniminuto.edu\Capresoca\AlmostClear\SIE\Aseguramiento\Red De servicios Asignada\Reporte_Red Asignada General_2025_10_26.csv"

# Ruta de salida
output_path = r"\\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\User_Df.TXT"
SAVE_DIR = r"\\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS"

# %%
Contracena = "None"
Correo = "aseg13@capresoc.onmicrosoft.com"

# %% [markdown]
# # 2. Lectura de Datafarmes

# %%
# Obtener todos los archivos .VAL en la ruta
val_files = [f for f in os.listdir(R_Automatico_S1) if f.endswith('.VAL')]

# Leer los archivos .VAL en un DataFrame
dataframes = []
for file in val_files:
    file_path = os.path.join(R_Automatico_S1, file)
    df = pd.read_csv(file_path, sep=',', encoding='ansi', header=None, dtype=str)
    dataframes.append(df)

# Concatenar todos los DataFrames en uno solo
df_Auto_S1 = pd.concat(dataframes, ignore_index=True)
# Cargar el archivo .txt en un DataFrame
df_municipios = pd.read_csv(R_Municipios, sep=';', encoding='utf-8', header=0, dtype=str)
df_Red_Servicios = pd.read_csv(R_Red_Servicios, sep=';', encoding='ANSI', header=0, dtype=str)

# Cargar el archivo Excel en un DataFrame, leyendo todos los datos como tipo str
#df_ms_sie = pd.read_excel(R_MS_SIE, sheet_name="Sheet1", dtype=str)
df_ms_sie = pd.read_csv(R_MS_SIE, sep=';', encoding='ANSI', header=0, dtype=str)

# Cargar el archivo Excel en un DataFrame, leyendo todos los datos como tipo str
df_Sisben= pd.read_excel(R_Sisben, sheet_name="Resultado", dtype=str)

# %%
print(df_Red_Servicios.columns.tolist())
df_Red_Servicios = df_Red_Servicios.drop(columns=["nit", "codigo", "Unnamed: 7"])
print("Nuevas columnas en df_Red_Servicios:", df_Red_Servicios.columns.tolist())
# Out:
# ['nit', 'razon_social', 'abreviatura', 'numero_identificacion', 'municipio', 'codigo', 'servicio', 'Unnamed: 7']
# Nuevas columnas en df_Red_Servicios: ['razon_social', 'abreviatura', 'numero_identificacion', 'municipio', 'servicio']

# %%
print(df_Red_Servicios["servicio"].unique())
print("Cantidad de registros antes:", df_Red_Servicios.shape[0])
# Out:
# ['MEDICAMENTOS' 'OPTOMETRIA' 'ODONTOLOGIA GENERAL' 'LABORATORIO CLINICO'
#  'MEDICINA GENERAL' 'MEDICAMENTOS ESPECIALIZADOS' 'OFTALMOLOGIA'
#  'ANESTESIA' 'SERVICIO FARMACEUTICO' 'ENFERMERIA'
#  'FONOAUDIOLOGIA Y/O TERAPIA DEL LENGUAJE' 'TERAPIA OCUPACIONAL'
#  'TERAPIA RESPIRATORIA' 'FISIOTERAPIA' 'MEDICINA FAMILIAR'
#  'PROMOCION Y PREVENCION GENERAL' 'RUTA MATERNO PERINATAL'
#  'SERVICIO DE DEMANDA INDUCIDA A LOS PROGRAMAS DE DETECCION TEMPRANA Y PROTECCION ESPECIFICA'
#  'PROCEDIMIENTOS MENORES' 'HOSPITALIZACION GENERAL'
#  'TRANSPORTE ASISTENCIAL MEDICALIZADO' 'SERVICIO DE URGENCIAS'
#  'TRANSPORTE ASISTENCIAL BASICO' 'RAYOS X'
#  'RUTA PROMOCION Y MANTENIMIENTO' 'IMAGENES DIAGNOSTICAS - IONIZANTES'
#  'PROTECCION ESPECIFICA - VACUNACION' 'NUTRICION Y DIETETICA'
#  'TOMA DE MUESTRAS DE LABORATORIO CLINICO' 'CIRUGIA ORTOPEDICA'
#  'INFECTOLOGIA']
# Cantidad de registros antes: 2937508

# %%
df_Red_Servicios = df_Red_Servicios[df_Red_Servicios['servicio'].isin(['MEDICINA GENERAL', 'ODONTOLOGIA GENERAL'])]
print("Cantidad de registros antes:", df_Red_Servicios.shape[0])
# Out:
# Cantidad de registros antes: 382013

# %%
from tabulate import tabulate

registro = df_Red_Servicios[df_Red_Servicios['numero_identificacion'] == "1246129076"]
# Filtrar el registro donde 'numero_identificacion' es "1116542442"
print(tabulate(registro, headers='keys', tablefmt='psql'))
# Out:
# +---------+---------------------------------------+---------------+-------------------------+-------------+---------------------+
# |         | razon_social                          | abreviatura   |   numero_identificacion | municipio   | servicio            |
# |---------+---------------------------------------+---------------+-------------------------+-------------+---------------------|
# | 1285838 | EMPRESA SOCIAL DEL ESTADO SALUD YOPAL | RC            |              1246129076 | Yopal       | ODONTOLOGIA GENERAL |
# | 1285842 | EMPRESA SOCIAL DEL ESTADO SALUD YOPAL | RC            |              1246129076 | Yopal       | MEDICINA GENERAL    |
# +---------+---------------------------------------+---------------+-------------------------+-------------+---------------------+

# %%
print("Cantidad de registros antes:", df_Red_Servicios.shape[0])

df_Red_Servicios = df_Red_Servicios.pivot_table(
    index=['abreviatura', 'numero_identificacion'],
    columns='servicio',
    values='razon_social',
    aggfunc='first'
).reset_index()

print("Cantidad de registros después:", df_Red_Servicios.shape[0])
df_Red_Servicios
# Out:
# Cantidad de registros antes: 382013
# Cantidad de registros después: 197661
# servicio abreviatura numero_identificacion  \
# 0                 AS            85001A0001
# 1                 AS             85001D001
# 2                 AS             85001D006
# 3                 AS             85001D007
# 4                 AS             85001D037
# ...              ...                   ...
# 197656            TI         RAN1117323746
# 197657            TI         RAN1118776184
# 197658            TI         RAN1120361085
# 197659            TI            W1W0250799
# 197660            TI            X2L0251521
#
# servicio                       MEDICINA GENERAL  \
# 0         EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 1         EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 2         EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 3         EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 4         EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# ...                                         ...
# 197656                 RED SALUD CASANARE E.S.E
# 197657                 RED SALUD CASANARE E.S.E
# 197658                 RED SALUD CASANARE E.S.E
# 197659    EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 197660                 RED SALUD CASANARE E.S.E
#
# servicio                    ODONTOLOGIA GENERAL
# 0         EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 197656                 RED SALUD CASANARE E.S.E
# 197657                 RED SALUD CASANARE E.S.E
# 197658                 RED SALUD CASANARE E.S.E
# 197659                                      NaN
# 197660                 RED SALUD CASANARE E.S.E
#
# [197661 rows x 4 columns]

# %%
# Crear la columna "Código Municipio" en df_Auto_S1 unificando las columnas 17 y 18
df_Auto_S1['Código Municipio'] = df_Auto_S1[17].str.zfill(2) + df_Auto_S1[18].str.zfill(3)

# Realizar el merge para traer la columna "Nombre Municipio" desde df_municipios
df_Auto_S1 = df_Auto_S1.merge(df_municipios[['CODIGO', 'Nombre Municipio']],
                              left_on='Código Municipio', right_on='CODIGO', how='left')

# Eliminar la columna 'CODIGO' que se agregó durante el merge
df_Auto_S1 = df_Auto_S1.drop(columns=['CODIGO'])

# %%
print(f"La cantidad de registros en df_Auto_S1 es: {df_Auto_S1.shape[0]}")
df_Auto_S1 = df_Auto_S1.drop_duplicates(subset=[1, 2])
df_Auto_S1_filtered = df_Auto_S1[df_Auto_S1[32] == "EPS025"]
df_Auto_S1_filtered = df_Auto_S1[df_Auto_S1[17] == 85]
print(f"La cantidad de registros en df_Auto_S1 es: {df_Auto_S1.shape[0]}")
# Out:
# La cantidad de registros en df_Auto_S1 es: 2840
# La cantidad de registros en df_Auto_S1 es: 2828

# %%
# Unir df_Auto_S1 con df_ms_sie para traer la columna correo_electronico
df_Auto_S1 = df_Auto_S1.merge(df_ms_sie[['numero_identificacion', 'correo_electronico']],
                              left_on=2, right_on='numero_identificacion', how='left')

# Eliminar la columna 'numero_identificacion' que se agregó durante el merge
df_Auto_S1 = df_Auto_S1.drop(columns=['numero_identificacion'])

# %%
num_empty = df_Auto_S1['correo_electronico'].isna().sum()
num_not_empty = df_Auto_S1['correo_electronico'].notna().sum()

print(f"Número de registros vacíos en 'correo_electronico': {num_empty}")
print(f"Número de registros no vacíos en 'correo_electronico': {num_not_empty}")
# Out:
# Número de registros vacíos en 'correo_electronico': 538
# Número de registros no vacíos en 'correo_electronico': 2292

# %%
# Mostrar la cantidad de registros vacíos antes del proceso
print(f"Registros vacíos en 'correo_electronico' antes del proceso: {df_Auto_S1['correo_electronico'].isna().sum()}")

# Filtrar los valores no deseados en la columna 'correo_electronico'
df_Auto_S1 = df_Auto_S1[~df_Auto_S1['correo_electronico'].str.contains(r'actua|notie|sincorr', case=False, na=False)]
df_Auto_S1['correo_electronico'] = df_Auto_S1['correo_electronico'].apply(
    lambda email: "" if isinstance(email, str) and (
        re.search(r'sincorreo', email, re.IGNORECASE) or 
        re.search(r'notiene', email, re.IGNORECASE) or 
        re.search(r'TRASLADO', email, re.IGNORECASE) or 
        re.search(r'ACTUALIZAR', email, re.IGNORECASE) or 
        re.search(r'actualiza', email, re.IGNORECASE) or 
        re.search(r'actualizar', email, re.IGNORECASE) or 
        re.search(r'tiene', email, re.IGNORECASE) or 
        re.search(r'TIENE', email, re.IGNORECASE) or 
        re.search(r'afilia', email, re.IGNORECASE) or 
        re.search(r'traslado', email, re.IGNORECASE) or 
        email.split('@')[0].isdigit()
    ) else email
)

# Mostrar la cantidad de registros vacíos después del proceso
print(f"Registros vacíos en 'correo_electronico' después del proceso: {df_Auto_S1['correo_electronico'].isna().sum()}")
# Out:
# Registros vacíos en 'correo_electronico' antes del proceso: 538
# Registros vacíos en 'correo_electronico' después del proceso: 538

# %%
# Mostrar la cantidad de registros vacíos antes del proceso
print(f"Registros vacíos en 'correo_electronico' antes del proceso: {df_Auto_S1['correo_electronico'].isna().sum()}")

# Realizar el merge para buscar correos en df_Sisben
df_Auto_S1 = df_Auto_S1.merge(df_Sisben[['numeroDocumento', 'email_contacto']],
                              left_on=2, right_on='numeroDocumento', how='left')

# Rellenar los valores vacíos en 'correo_electronico' con los valores de 'email_contacto'
df_Auto_S1['correo_electronico'] = df_Auto_S1['correo_electronico'].fillna(df_Auto_S1['email_contacto'])

# Eliminar la columna 'email_contacto' y 'numeroDocumento' que se agregó durante el merge
df_Auto_S1 = df_Auto_S1.drop(columns=['email_contacto', 'numeroDocumento'])

# Mostrar la cantidad de registros vacíos después del proceso
print(f"Registros vacíos en 'correo_electronico' después del proceso: {df_Auto_S1['correo_electronico'].isna().sum()}")
# Out:
# Registros vacíos en 'correo_electronico' antes del proceso: 538
# Registros vacíos en 'correo_electronico' después del proceso: 351

# %%
# Mostrar la cantidad de registros vacíos antes del proceso
print(f"Registros vacíos en 'correo_electronico' antes del proceso: {df_Auto_S1['correo_electronico'].isna().sum()}")

# Filtrar los valores no deseados en la columna 'correo_electronico'
df_Auto_S1 = df_Auto_S1[~df_Auto_S1['correo_electronico'].str.contains(r'actua|notie|sincorr', case=False, na=False)]
df_Auto_S1['correo_electronico'] = df_Auto_S1['correo_electronico'].apply(
    lambda email: "" if isinstance(email, str) and (
        re.search(r'sincorreo', email, re.IGNORECASE) or 
        re.search(r'notiene', email, re.IGNORECASE) or 
        re.search(r'TRASLADO', email, re.IGNORECASE) or 
        re.search(r'ACTUALIZAR', email, re.IGNORECASE) or 
        re.search(r'actualiza', email, re.IGNORECASE) or 
        re.search(r'actualizar', email, re.IGNORECASE) or 
        re.search(r'tiene', email, re.IGNORECASE) or 
        re.search(r'TIENE', email, re.IGNORECASE) or 
        re.search(r'afilia', email, re.IGNORECASE) or 
        re.search(r'traslado', email, re.IGNORECASE) or 
        email.split('@')[0].isdigit()
    ) else email
)

# Mostrar la cantidad de registros vacíos después del proceso
print(f"Registros vacíos en 'correo_electronico' después del proceso: {df_Auto_S1['correo_electronico'].isna().sum()}")
# Out:
# Registros vacíos en 'correo_electronico' antes del proceso: 351
# Registros vacíos en 'correo_electronico' después del proceso: 351

# %%
df_Auto_S1 = df_Auto_S1.dropna(subset=['correo_electronico'])

# %%
# Función para corregir un correo electrónico
def fix_email(email):
    if pd.isna(email):
        return email
    # Quitar todos los espacios
    new_email = email.replace(" ", "")
    # Si el correo termina en "com." o "COM." (ignorando mayúsculas) quitar el punto final
    if new_email.lower().endswith("com."):
        new_email = new_email[:-1]
    return new_email

# Aplicar la corrección y contar cuántos registros se modificaron
original_emails = df_Auto_S1['correo_electronico']
corrected_emails = original_emails.apply(fix_email)
num_corrected = (original_emails != corrected_emails).sum()

# Actualizar la columna con las correcciones
df_Auto_S1['correo_electronico'] = corrected_emails

print(f"Se corrigieron {num_corrected} registros en 'correo_electronico'.")
# Out:
# Se corrigieron 4 registros en 'correo_electronico'.

# %%
df_Auto_S1 = df_Auto_S1.merge(
    df_Red_Servicios[['numero_identificacion', 'MEDICINA GENERAL', 'ODONTOLOGIA GENERAL']],
    left_on=10,
    right_on='numero_identificacion',
    how='left'
)
# (Optional) Drop the duplicate 'numero_identificacion' column if no longer needed:
df_Auto_S1 = df_Auto_S1.drop(columns=['numero_identificacion'])

# %%
mask = (
    df_Auto_S1['MEDICINA GENERAL'].notna() &
    (df_Auto_S1['MEDICINA GENERAL'].astype(str).str.strip() != '') &
    df_Auto_S1['ODONTOLOGIA GENERAL'].notna() &
    (df_Auto_S1['ODONTOLOGIA GENERAL'].astype(str).str.strip() != '')
)
df_Auto_S1 = df_Auto_S1[mask]

print("Cantidad de registros después del filtrado:", df_Auto_S1.shape[0])
# Out:
# Cantidad de registros después del filtrado: 1697

# %%
df_Auto_S1
# Out:
#            0   1           2        3          4         5          6  \
# 0     EPS025  CC  1000579442   LUCUMI     CORTES     LIBNI    VIVIANA
# 1     EPS025  CC  1002270577  FUENTES   ALVARADO      LINA    MARCELA
# 2     EPS025  CC  1002603243     PAEZ     PATIÑO  YAKELINE        NaN
# 3     EPS025  CC  1002645522  PACAGUI   AFRICANO      YOHN  ALEXANDER
# 4     EPS025  CC  1002758775   ZARATE  SARMIENTO     ABNER      ELIUD
# ...      ...  ..         ...      ...        ...       ...        ...
# 1735  EPS025  CC    74301649   RINCON   GONZALEZ      OMAR    ALBERTO
# 1736  EPS025  CC  1115911152  AREVALO    CUBIDES     MAILY     JERAXY
# 1737  EPS025  CC    79271536     ALBA      GOMEZ   ORLANDO        NaN
# 1738  EPS025  RC  1222147094   ARAQUE     VARGAS  EMILIANO        NaN
# 1739  EPS025  RC  1118580072     VERA    BARRERA     JHOEL  ALEJANDRO
#
#                7  8   9  ...   35     36   37 38   39 Código Municipio  \
# 0     12/11/2001  F  CC  ...  COL  85001  COL  F  NaN            85001
# 1     08/11/2001  F  CC  ...  COL  85125  COL  F  NaN            85125
# 2     27/10/1994  F  CC  ...  COL  85015  COL  F  NaN            85015
# 3     26/12/2001  M  CC  ...  COL  85001  COL  M  NaN            85001
# 4     05/02/2003  M  CC  ...  COL  85410  COL  M  NaN            85410
# ...          ... ..  ..  ...  ...    ...  ... ..  ...              ...
# 1735  18/09/1971  M  CC  ...  COL  85010  COL  M  NaN            85010
# 1736  13/03/2006  F  CC  ...  COL  85010  COL  F  NaN            85010
# 1737  28/11/1962  M  CC  ...  COL  11001  COL  M  NaN            85250
# 1738  06/03/2025  M  RC  ...  COL  85001  COL  M  NaN            85001
# 1739  21/01/2021  M  RC  ...  COL  85001  COL  M  NaN            85001
#
#      Nombre Municipio          correo_electronico  \
# 0               YOPAL                no@gmail.com
# 1        HATO COROZAL  linamarcela08910@gmail.com
# 2             CHÁMEZA        yakes-97@hotmail.com
# 3               YOPAL   pacaguiafricano@gmail.com
# 4           TAURAMENA  ELIUDSARMIENTO19@GMAIL.COM
# ...               ...                         ...
# 1735          AGUAZUL          manoklito@yahoo.es
# 1736          AGUAZUL     mailyjeraxy13@gmail.com
# 1737   PAZ DE ARIPORO   orlandogomez536@gmail.com
# 1738            YOPAL     anavargas0796@gmail.com
# 1739            YOPAL   angelita94_03@hotmail.com
#
#                                     MEDICINA GENERAL  \
# 0              EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 1                           RED SALUD CASANARE E.S.E
# 2                           RED SALUD CASANARE E.S.E
# 3              EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 4                  E.S.E HOSPITAL LOCAL DE TAURAMENA
# ...                                              ...
# 1735  HOSPITAL DE AGUAZUL JUAN HERNANDO URREGO E.S.E
# 1736  HOSPITAL DE AGUAZUL JUAN HERNANDO URREGO E.S.E
# 1737           EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 1738           EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 1739           EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
#
#                                  ODONTOLOGIA GENERAL
# 0              EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 1                           RED SALUD CASANARE E.S.E
# 2                           RED SALUD CASANARE E.S.E
# 3              EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 4                  E.S.E HOSPITAL LOCAL DE TAURAMENA
# ...                                              ...
# 1735  HOSPITAL DE AGUAZUL JUAN HERNANDO URREGO E.S.E
# 1736  HOSPITAL DE AGUAZUL JUAN HERNANDO URREGO E.S.E
# 1737           EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 1738           EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
# 1739           EMPRESA SOCIAL DEL ESTADO SALUD YOPAL
#
# [1697 rows x 45 columns]

# %%
df_Auto_S1 = df_Auto_S1.drop_duplicates(subset=[9, 10])
print("Cantidad de registros únicos según el id (columnas 9 y 10):", df_Auto_S1.shape[0])
# Out:
# Cantidad de registros únicos según el id (columnas 9 y 10): 1609

# %%
# Guardar el DataFrame df_Auto_S1 en la ruta especificada
df_Auto_S1.to_csv(output_path, sep=',', encoding='ansi', index=False)

# %% [markdown]
# # 2 prueba

# %%
import os
import ctypes

# 1) Asegurarte de apuntar a la carpeta de MSYS2 mingw64\bin
os.add_dll_directory(r"C:\msys64\mingw64\bin")

# 2) (Opcional) Cargar manualmente una o varias DLL si deseas comprobar:
dll_gobject = ctypes.CDLL("libgobject-2.0-0.dll")
dll_pangoft2 = ctypes.CDLL("libpangoft2-1.0-0.dll")
dll_pango   = ctypes.CDLL("libpango-1.0-0.dll")
dll_fontconfig = ctypes.CDLL("libfontconfig-1.dll")
# ... etc.

# 3) Recién ahora importar las librerías que usarán WeasyPrint o GTK
import pandas as pd
import smtplib
import datetime
import pdfkit
from weasyprint import HTML
from email import generator
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from fpdf import FPDF



# Si deseas usar win32com (automatización de Outlook) en lugar de smtplib, cambia a True.
USE_WIN32COM = True

if USE_WIN32COM:
    import win32com.client as win32

# ------------------------------------------------------------------------
# CONFIGURACIÓN DE CORREO (SMTP / Outlook)
# ------------------------------------------------------------------------
# Para smtplib (si USE_WIN32COM es False):
SMTP_SERVER = "smtp-mail.outlook.com"  # Ejemplo para Outlook
SMTP_PORT = 587
#SMTP_USERNAME = "rincon3259@gmail.com"
#SMTP_PASSWORD = "hdyx atvw ncdq otgw"  # Contraseña de aplicación si tienes 2FA "rincon3259@gmail.com"
SMTP_USERNAME = Correo
SMTP_PASSWORD = Contracena
FROM_NAME = "Capresoca EPS"  # Cómo se mostrará el remitente

# Correo principal y copia
# Ahora, cada correo se enviará a la dirección especificada en la columna "correo_electronico"
# de cada fila del DataFrame Df_Prueba, por lo que no es necesario definir un TO_EMAIL fijo.
#TO_EMAIL = ""
CC_EMAIL = ""

#TO_EMAIL = "rincon3259@gmail.com"
#CC_EMAIL = "marcopolo3259@gmail.com"

# ------------------------------------------------------------------------
# ENCABEZADO (HTML) + CUERPO DEL MENSAJE
# ------------------------------------------------------------------------
EMAIL_TEMPLATE = """\
<html>
<head>
    <meta charset="utf-8">
</head>
<body style="font-family: Arial, sans-serif; font-size: 14px;">

    <!-- Encabezado con imagen a la izquierda y textos a la derecha -->
    <table width="100%" style="border-collapse: collapse;">
    <tr>
        <!-- Columna izquierda: imagen + NIT + EPS -->
        <td width="150" style="vertical-align: top;">
            <img src="cid:capre.png" alt="Capresoca"
                width="150"
                style="width:150px; height:auto; display:block;"
                border="0">
            <br><br>
            <span style="font-family: Arial, sans-serif; font-size: 14px;">
                NIT. 891.856.000-7<br>
                EPS en intervención
            </span>
        </td>
        <!-- Columna derecha: textos centrados -->
        <td style="vertical-align: top; text-align: center;">
        <span style="font-family: Arial, sans-serif; font-size: 16px; font-weight: bold;">
            COMUNICACIÓN INSTITUCIONAL
        </span><br><br>
        <span style="font-family: Arial, sans-serif; font-size: 14px;">FO-GD-01</span><br>
        <span style="font-family: Arial, sans-serif; font-size: 14px;">2024-01-19</span><br>
        <span style="font-family: Arial, sans-serif; font-size: 14px;">V.03</span>
        </td>
    </tr>
    </table>

    <hr>

    <!-- Cuerpo del mensaje -->
    <p>{Fecha_Documento}</p>
    <p>
        Señor (a)<br>
        <strong>{col5} {col6} {col3} {col4}</strong><br>
        <strong>{col1} {col2}</strong><br>
        <strong>{municipio} {cod_municipio}</strong>
    </p>
    <p><strong>Ref.: {Asunto}</strong></p>
    <p>
        Cordial saludo,<br><br>
        Comprometidos con el Sistema General de Seguridad Social en Salud (SGSSS), atendiendo, entre otros,
        los principios de universalidad, continuidad y, considerando que usted no reporta la novedad de Movilidad a pesar
        de cumplir con los requisitos para ello (Tener Sisbén metodología IV actualizada, o pertenecer a listado censal),
        se está dando aplicación a lo definido en la normativa vigente para mitigar el riesgo y/o afectación en la
        continuidad de la afiliación, como de la prestación de los servicios de salud.
    </p>
    <p>
        Por lo anterior y en virtud del debido proceso, formalmente le comunicamos que, a la fecha conforme a lo
        definido por el Ministerio de Salud y Protección Social en Salud, en el Decreto 064 de 2020:<br>
        Artículo 7º- modificación del artículo 2.1.7.8 del Decreto 780 de 2016 ‘registro y reporte de la novedad de
        movilidad’:
        <em>“(…) Cuando el usuario no registre la solicitud de movilidad del régimen contributivo al régimen subsidiado,
        la EPS deberá reportarla en la BDUA e informar al afiliado y a la respectiva entidad territorial, tal novedad (…)”</em>.
    </p>
    <p>
        En efecto, Capresoca EPS, le informa que se aplicó la novedad de Movilidad al Régimen Subsidiado y continúan con
        la prestación de los servicios de salud en nuestra EPS y la IPS que le prestará los servicios de salud en
        medicina general es {Medicina} y los servicios de odontología es {Odontologia}. 
        Para más información puede ser consultada en los móviles: 3106805416 – 3229467854.
    </p>
    <p>
        Asimismo, los afiliados tienen la posibilidad de consultar su red de servicios de salud a través del siguiente
        enlace:
        <a href="http://capresoca.gov.co:/app_sie/loginAffiliate.xhtml#nbb">
        http://capresoca.gov.co:/app_sie/loginAffiliate.xhtml#nbb</a>.
        Para acceder, deben seleccionar la opción “CREACIÓN de USUARIO AFILIADO” e ingresar los datos básicos necesarios
        para obtener una clave que les permitirá consultar y descargar información sobre los servicios disponibles
        en la red primaria de salud.
    </p>
    <p>
        <img src="cid:yesid_firma.png" alt="Firma" style="height: 100px;"><br><br>
        <strong>Osmar Yesid Rincon Zorro, Profesional de Apoyo de Aseguramiento</strong>
    </p>
</body>
</html>
"""

# ------------------------------------------------------------------------
# FUNCIÓN PARA ENVIAR EL CORREO
# ------------------------------------------------------------------------
def send_email_with_header(row):
    """
    Envía un correo para la fila `row` del DataFrame utilizando la plantilla HTML.
    Si USE_WIN32COM es True se utiliza Outlook mediante win32com, de lo contrario se usa smtplib.
    
    Por ahora se envía a un correo fijo (TO_EMAIL) con copia (CC_EMAIL). 
    La lógica para usar row["correo_electronico"] está comentada para este ejemplo.
    """
    to_email = row["correo_electronico"]
    cc_email = CC_EMAIL

    # Usar la variable global Asunto en el formateo de la plantilla.
    email_body = EMAIL_TEMPLATE.format(
        col5=row[5],
        col6=row[6],
        col3=row[3],
        col4=row[4],
        col1=row[1],
        col2=row[2],
        municipio=row["Nombre Municipio"],
        cod_municipio=row["Código Municipio"],
        Medicina=row["MEDICINA GENERAL"],
        Odontologia=row["ODONTOLOGIA GENERAL"],
        Asunto=Asunto,
        Fecha_Documento = Fecha_Documento
    )

    if USE_WIN32COM:
        try:
            outlook = win32.Dispatch('Outlook.Application')
            mail = outlook.CreateItem(0)  # 0: MailItem
            mail.To = to_email
            mail.CC = cc_email
            mail.Subject = "Notificación Movilidad al Régimen Subsidiado"
            mail.HTMLBody = email_body
            
            try:
                with open(r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\capre.png", 'rb') as f:
                    img_data = f.read()
                image = mail.Attachments.Add(r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\capre.png")
                image.PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "capre.png")
            except Exception as e_img:
                print(f"Error al incrustar capre.png: {e_img}")
            
            try:
                with open(r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\YESID.png", 'rb') as f:
                    firma_data = f.read()
                firma_image = mail.Attachments.Add(r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\YESID.png")
                firma_image.PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "yesid_firma.png")
            except Exception as e_firma:
                print(f"Error al incrustar YESID.png: {e_firma}")

            mail.Send()
            print(f"Correo enviado con éxito a {to_email} (CC: {cc_email}) vía Outlook.")
        except Exception as e:
            print(f"Error al enviar correo vía Outlook: {e}")
    else:
        msg = MIMEMultipart('related')
        msg['Subject'] = "Notificación Movilidad al Régimen Subsidiado"
        msg['From'] = f"{FROM_NAME} <{SMTP_USERNAME}>"
        msg['To'] = to_email
        msg['Cc'] = cc_email
        to_addresses = [to_email, cc_email]

        msg.attach(MIMEText(email_body, 'html'))

        try:
            with open(r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\capre.png", 'rb') as f:
                img_data = f.read()
            image = MIMEImage(img_data, name='capre.png')
            image.add_header('Content-ID', '<capre.png>')
            msg.attach(image)
        except Exception as e_img:
            print(f"Error al leer la imagen capre.png: {e_img}")

        try:
            with open(r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\YESID.png", 'rb') as f:
                firma_data = f.read()
            firma_image = MIMEImage(firma_data, name='YESID.png')
            firma_image.add_header('Content-ID', '<yesid_firma.png>')
            msg.attach(firma_image)
        except Exception as e_firma:
            print(f"Error al leer la imagen YESID.png: {e_firma}")

        try:
            with smtplib.SMTP(SMTP_SERVER, SMTP_PORT) as server:
                server.starttls()
                server.login(SMTP_USERNAME, SMTP_PASSWORD)
                server.send_message(msg, from_addr=msg['From'], to_addrs=to_addresses)
            print(f"Correo enviado con éxito a {to_email} (CC: {cc_email}) vía smtplib.")
        except Exception as e:
            print(f"Error al enviar el correo a {to_email}: {e}")

# ------------------------------------------------------------------------
# FUNCIÓN PARA GENERAR PDF POR MUNICIPIO
# ------------------------------------------------------------------------
def generate_pdf_for_municipality(municipality_rows, municipality_name):
    """
    Crea un PDF que contiene el contenido HTML completo (con imágenes) de todos los correos
    para el municipio 'municipality_name'. Cada correo se muestra en una página separada
    e incluye la información de envío (De, Enviado el, Para y Asunto).

    Se guardará en: SAVE_DIR/Correo_{municipality_name}_Movilidad064_Diciembre_2024.pdf

    Se usa WeasyPrint para generar el PDF.
    """
    # Rutas de las imágenes (asegúrate que sean correctas)
    Logo_Capresoca = r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\capre.png"
    yesid_firma_path = r"C:\Users\osmarrincon\OneDrive - 891856000_CAPRESOCA E P S\Imágenes\YESID.png"
    
    pdf_filename = f"Correo_{municipality_name}_{Archivo_Name}.pdf"
    pdf_path = os.path.join(SAVE_DIR, pdf_filename)
    
    # CSS para estilos y para forzar salto de página en cada correo
    css = """
    <style>
      .correo-container {
        page-break-after: always;
        margin-bottom: 20px;
      }
      .meta-info {
        font-family: Arial, sans-serif;
        font-size: 14px;
        margin-bottom: 10px;
      }
      .meta-info p {
        margin: 2px 0;
      }
    </style>
    """
    
    # Se inicia el HTML con CSS
    html_contents = css

    # Recorremos cada registro para armar su contenido
    for idx, row in municipality_rows.iterrows():
        # Variables de metadatos: Se usa la variable global Fecha y Asunto
        de_val = row.get("De", "ASEGURAMIENTO CAPRESOCA EPS")
        fecha_val = row.get("FechaEnvio", Fecha)  # Utiliza la variable global Fecha
        asunto_val = row.get("Asunto", Asunto)      # Utiliza la variable global Asunto
        para_val = row.get("correo_electronico", "alegunamaria2014@gmail.com")
        
        # Bloque de metadatos del correo
        meta_html = f"""
        <div class="meta-info">
            <p><strong>De:</strong> {de_val}</p>
            <p><strong>Enviado el:</strong> {fecha_val}</p>
            <p><strong>Para:</strong> {para_val}</p>
            <p><strong>Asunto:</strong> {asunto_val}</p>
        </div>
        """
        
        # Construir el cuerpo del correo usando la plantilla existente.
        # Se agrega Asunto=Asunto para formatear la plantilla global, la cual utiliza {Asunto}.
        email_html = EMAIL_TEMPLATE.format(
            col5=row[5],
            col6=row[6],
            col3=row[3],
            col4=row[4],
            col1=row[1],
            col2=row[2],
            municipio=row["Nombre Municipio"],
            cod_municipio=row["Código Municipio"],
            Medicina=row["MEDICINA GENERAL"],
            Odontologia=row["ODONTOLOGIA GENERAL"],
            Asunto=Asunto,
            Fecha_Documento = Fecha_Documento
        )
        # Reemplazar las referencias CID por rutas absolutas usando "file:///"
        email_html = email_html.replace('cid:capre.png', "file:///" + Logo_Capresoca.replace("\\", "/"))
        email_html = email_html.replace('cid:yesid_firma.png', "file:///" + yesid_firma_path.replace("\\", "/"))
        
        # Envolver el contenido del correo en un contenedor que forza salto de página
        correo_html = f"""
        <div class="correo-container">
            {meta_html}
            {email_html}
        </div>
        """
        
        html_contents += correo_html
    
    try:
        # Generar el PDF usando WeasyPrint
        HTML(string=html_contents, base_url='file:///' + os.path.abspath('.')).write_pdf(pdf_path)
        print(f"PDF generado para municipio {municipality_name}: {pdf_path}")
    except Exception as e:
        print(f"Error al generar el PDF: {e}")


# ------------------------------------------------------------------------
# PROCESO PRINCIPAL
# ------------------------------------------------------------------------
def main():
    
    # 1) Enviar un correo por cada registro
    for index, row in df_Auto_S1.iterrows():
        send_email_with_header(row)

    # 2) Generar un PDF por cada municipio
    grouped = df_Auto_S1.groupby("Nombre Municipio")
    for municipality_name, group_df in grouped:
        generate_pdf_for_municipality(group_df, municipality_name)

    print("Proceso completado.")

if __name__ == "__main__":
    main()
# Out:
# Correo enviado con éxito a no@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a linamarcela08910@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yakes-97@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a pacaguiafricano@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ELIUDSARMIENTO19@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a alecondia245@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jhonardila@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ad4469237@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carlosvides@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a JHONFREDY2014-2015@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a sebastian-0550@outlook.com (CC: ) vía Outlook.
# Correo enviado con éxito a av3460318@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a caperatapiaeilsa@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jhonrc1507@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marlysua01@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jaurinmoreno@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lauyisel321@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a arojas1106228@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a 1006424529miguel@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ac806043@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MIGELM08@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a YAMIDPARRA08@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a MISTERBOTIED@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a ALEJANDRO2004@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a tovarkatheribn58@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alejandravivas1991@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fredynaranjo29@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ykatherinec.88@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a DENNISMENDIVELSO127@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a GINABETANCOURTH10@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a karynaorostrinidad@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ismcas57@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a YULIETTABACO19@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a maittebenitez16@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a JORGEANDREGARRIDO323@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a yiverson12@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a albaponare@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a miguelangelpodar@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a construccioncoleg23@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a geinerdanilo2021@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MARIAYULIANASOLERPEDREROS@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a barahonaestevan0@hootmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dv868519@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a linamaecelagaitan50@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a melisajimenez582@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a estersanchez0219@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andresinocencio2701@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a camicris2470@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a kayuunro2003@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carlosmendivelso04@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a UNDAJEFERSON@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a JEFFERSONMOM2345@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a hsemssp@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a rortiz3@unab.edu.co (CC: ) vía Outlook.
# Correo enviado con éxito a correo@correo.com (CC: ) vía Outlook.
# Correo enviado con éxito a ARIZACHARLI05@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a maquinine.gesocial@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a taniamoya546@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a leandro-27crespo@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cabildoc.mochuelo2017@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a achaguadayana70@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a DIANAMARCELASALINAS04@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a avispitaavispita309@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MAIROZENY123@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a BAQUERORAMOSDEIVERALEXANDER@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a hectorquinche11@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a juanrodriguez@gmail.vom (CC: ) vía Outlook.
# Correo enviado con éxito a yurlenygomez1@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a baudiliogomez@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a 16yesid@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a neidersoga@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a qjesusdavid65@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a willintonespejo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a FABRICCIO1598@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a linagisellamateusr@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a practicante.comunicaciones@sanbartolo.edu.co (CC: ) vía Outlook.
# Correo enviado con éxito a analuciagarciabellizia@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yurleysmithparadaq@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LARCHILAMONTANEZ@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a eg297684@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luisalberto.49@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a javierolmos.soldado@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a consuelos.1609@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ALFONSOPEDROPABLO6@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a ANGELITHAPARRA03@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a efp2948@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a vargasemerson1427@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MARTOMGAND@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a laurayarenis95@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a utnutripaeyopal2023@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a emaedithriscanevo06@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a servicioach@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nathaliasanabria105@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lizethsan1968@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cuervoerika125@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a FABIAN328ALFONSO@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a aldom04@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jimeneznidia36@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a salcedodavid339@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carolinacespedes2308@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luisrojas2787@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a RODRIGUEZESPINOSA08@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a LADINOSNEIDER07@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a shelsysuarez43@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a heidyvargas207@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a angelatatianaromerocardenas7@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SISBEN@YOPAL-CASANARE.GOV.CO (CC: ) vía Outlook.
# Correo enviado con éxito a ibo937211@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a elkingome16@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jasbleidycalderon773@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a piratequesebastian542@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a angelytatianaamezquitagalindo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MIGUELVELASCO1029@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a COMPRASSERV2025@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a thaliacepeda@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a BARRERAUNVIVIO@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a dorisdelfinacruzh@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a denisbaqueroww2017@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a daryisespinosa@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dannassofiaadan2002@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a camiloandreysiabatoperez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sebastiandiaz@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SISBEN@YOPAL-CASANARE.GOV.CO (CC: ) vía Outlook.
# Correo enviado con éxito a sharik16tatiana@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yaneth@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carmenrosacachayacevedo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a enlle0128@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a josediaz30agus@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a darwinlesmes2917@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a santiagodelgado.arj@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a diegovacav4@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edarwinmartinez1989@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a davidgonalvarezruiz27@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a elkinavella@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yormanmontana9@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a 2004.zharitho@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a erikacuesta09@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a gutierrezromerojulioalbeiro@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a murillosierra17@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a estefanybahamon54@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a info@itcasaciados.com (CC: ) vía Outlook.
# Correo enviado con éxito a ALBEIROREINA9@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a HUGOSARAZO@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a MARTHAMAHECHA@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a nicolash04@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a catirasg@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MORALESMARTINEZLAUDYSOFIA@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a velandiacristian2004@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yanyres23@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a asisadm.mecatsas@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a rosamilenacuevas28@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a santoschavezanargeni@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a fprocasanare@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ROMERO.ISRAEL1308@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a HEULERSOCHAMORALES@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a williamfabianmoralesochoa@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alexcano@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jahidyamarillo75@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LSALANUEVA19@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a aguilaaguirre01@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a meira.robles@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a JAR2004@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a fresajacone@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dilsacontreras407@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a hernan3028@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dilfreyc@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a vargasneila879@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cadenamildrey0@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edymarlenbernal@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a omarmr20@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MANILOSOGAMOSO@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a tatana-15@hormail.com (CC: ) vía Outlook.
# Correo enviado con éxito a geneshk8@gmail.comalia (CC: ) vía Outlook.
# Correo enviado con éxito a no-registra@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a crisrtiangarces1@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alixrodriguez86@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a tumayedwin556@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a oskarguevara-27@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ludyhumokcachay96@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a diana9897@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a senatalentohumano@soscontingencias.com.co (CC: ) vía Outlook.
# Correo enviado con éxito a brayanhl2523@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jimmygil@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a DAYANAGALVIS390@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a santospuertocarlosjulio@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a adrianav3620@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a TEWUAGO20@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a RECURSOHUMANOEIKOS@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a franzmendoza916@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a hARWINMUSIC17-@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a cepedapaola18@gmil.com (CC: ) vía Outlook.
# Correo enviado con éxito a MAICOLPALACIOS2784@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a arleyrojas@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lauracede13@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a GUTIERREZ2016282008@UNITROPICO.EDU.CO (CC: ) vía Outlook.
# Correo enviado con éxito a fresita-k28@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a eider220697@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a AH5669092@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a MARCELAPAEZ1996@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a yudiman1234@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fermaria1024@outolook.com (CC: ) vía Outlook.
# Correo enviado con éxito a lidiezithayaneth@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andreariveros0323@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alejandralievano10@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jrodriguezjz2023@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ANDRESMEDINA0112@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a leidyc.jimenez2021@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lorenaalarcon0509@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edisoncarreno89@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a RICAURTECAMARGOLUZNEYIS@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a javieralexanderguina@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yiye95@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a evelyndariana03@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a silviojosecarilloparales@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LEIDYPAODIAZ07@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a marthaquevedo702@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a bp03517@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a heilergomez1986@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a CLARA.PONARE123@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a maremartha32@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luzadrianahinojosagonzalez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edwinalexanderhume99@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a camilomahecha47@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edwinescobar0982@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a juandavidsuarezzorro358@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a claudiaamaya1298@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lesmescristian31@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a hidrogandia@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yibera21@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nestor_cubidesch@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a silviaarocha877@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SERVICIORINOCOYOPALES@MAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a andresperilla@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a vanegasluis106@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a leguizamonmones1480@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yisethsalinas@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nocorreo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fernanda_ovalle@cloud.com (CC: ) vía Outlook.
# Correo enviado con éxito a recursoshumanosdiazygil@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yuranyguavare123@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maickol.parrado@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lopezhernandezc36@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a blancanurybarrera26@gmial.com (CC: ) vía Outlook.
# Correo enviado con éxito a JCELY1703@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a calderonmoralesjhonatansmith@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SERVICIOACH@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a valen29martinez25@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a talentohumano@tecnimontajes.com.co (CC: ) vía Outlook.
# Correo enviado con éxito a DUVANMECHE31@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a ineldachaparro@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ARAGONCELYK@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a estepayuliana80@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a gbaltopo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a gestionhumana.jps@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a OLGUINR636@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a rosaelenamontañabarrera@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a G.FABIANOOTES@MAIL.VOM (CC: ) vía Outlook.
# Correo enviado con éxito a TVIRGILIA.27@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a andres.felipe2510@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a eduarvargas1118@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a moradaniela426@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mssphseq@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a susanga212014@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marcelanino62@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a PARASHENEYDERM@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a consultoriasyopal@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a solanororodriguez71@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a enamoradoerika846@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sove1804@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a emanuel03johan@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a XIMENA31110G@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a jhgonzalez920708@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SOYDELVERDE.FERCHIN@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a faunerdavi@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mayito.1009@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cristhianpj93@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a colombia123yopal@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a multiserviciosyopal@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sofi_nmh@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mayraunda8@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lagosmarlon95@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a paola202024@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fabianlopez3150@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a recursoshumanosdiazygil@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a vanessapeluxita@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a angiegh14@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ks6321604@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maidyavella1236@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a helen1995---@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a abglicethdiaz@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MARYIS9608@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a mariapbarrera82@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yolmanbarrera@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andersonye@axoda.org (CC: ) vía Outlook.
# Correo enviado con éxito a kevingranados.es@unitropico.edu.co (CC: ) vía Outlook.
# Correo enviado con éxito a danielpiraban98@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a NATALIEALEON371@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a carmenperezp05@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a karina311013@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a chaparrojaime52@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a PEREZFERNEY73@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a antonio19981@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ospinaricardo09@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fabianfermandezpiraban@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jhonatanstiven531@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alexguttierrez1@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ANOMI.VEGA@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a sebastiantenzao07@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yesidwilmer28@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a PRADAUVACARADEPASTELITO@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a fprocasanare@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a castillo1991maldonad0@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a linacruzsar@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mayren1989@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carmi2530@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a URBANOBEYER@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a didieralfredoluna@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nicaciogualdron@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yudymilena.2017@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a gerlycoba@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a eduardopregonero96@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a hugosazo@mail.com (CC: ) vía Outlook.
# Correo enviado con éxito a precasanare89@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a NACHITOMLENDEZ28@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a sanchezyadira35@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carranza1995rodriguez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yavimaramirezefrain@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a FABIANSUAREZ1987@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a jokkocusta@gufum.com (CC: ) vía Outlook.
# Correo enviado con éxito a dimargon05@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a judithsuerra68@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a baicueviatela@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lidabuitrago@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luzmaryf2025@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marinaxina@outlook.com (CC: ) vía Outlook.
# Correo enviado con éxito a yanierbarreto46@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yadilop10@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a siliso77@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lumybonilla-77@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ALEXANDRA1411DOMINGUEZ@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a dennise3150@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a romeirafm@gmil.con (CC: ) vía Outlook.
# Correo enviado con éxito a EDILMACASTRO978@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a luise09@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LITSHURY@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a fresajacone@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a paticocastro11@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mativera941@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a aguiarmileyde2020@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a deisyhiguera736@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a Esnnedaortegon01@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luzvega@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a rochidaza-@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marinelvaduenas@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lisbetgoyeneche@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a olganieto.puentes@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a audaloniagaravito@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a blanca.ines@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luzdajaramillo1974@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@orocue-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a LUISMARIO57@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a nelsonnenriquemoreno@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a hernandoteoduliorojas@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a chwpsaxo93@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sigmachse@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yesidmendezbriceno@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ARISTOBULOSPARRALES@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a lau1020@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a GERENCIA.AVANZAMOS@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a maoltomu@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andreajohanapongutamorales@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LUZMARINA_54@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a omairaramirez639@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luzaideegiraldo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a esperanzaruizmartinez2021@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yeni1976velandia@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dianapn78@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a univioluz22@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a deisyvivianarojas2708@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a YORLIPIRABAN@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a magda.ohana@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dorelisduran1978@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a beronicarueda974@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yury1983@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ammariaalejandra92@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a miriajoro25@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a olgaluciagaviria2020@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maryeparra81@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yayitanoguera85@hotmai.com (CC: ) vía Outlook.
# Correo enviado con éxito a criollopuerta@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carlosmipc2615@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a josejuaquinbelisario@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marcotulioromero@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a IVANDARIOIDANROA@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a MARCOROMERO@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a HUGOSARAZO@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a marisolrf18@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fprocasanare@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edwinmendivelso@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jeinerdiaz@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a aurelioholguin6@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jairgualdron91@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a YUBERSEBASTIA6@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a ERNESTOMENESPIO74@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a wtrswfrswfr5347@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a 8a.alex@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a flavoainestaladicheriscanevo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a juliomoreno7423@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a elizzrojas@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carlosmoralesariza@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a branleyvega@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a RECURSOSHUMANOS@COTRASNCOOP.LTDA (CC: ) vía Outlook.
# Correo enviado con éxito a pa394589@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LEONELROMEROB14@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a danielpulido1974@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lemusfidel75@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a miguelangel@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nestorjaviergutierrezflorez7@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luispan819@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LUZR8271@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a joropacolina36@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marthatuay835@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dumarcedeno@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a camachoangelmiro15@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a reinaldo.otero.l@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a daniloch65@homail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luismiguel@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sandraorentive33@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jeferssonmartinez5068@outlook.com (CC: ) vía Outlook.
# Correo enviado con éxito a liamcasallas15@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alonsolilibeth2023@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mvdelngton30@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a martinezkeiner398@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a NUEVOSISBEN2021@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a tentycardenas1975@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alonsolilibeth17@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a leithoncalasiabato@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alejasigua03@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a granadosjosehernando@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a arnoldtumay23@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MIC1454@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a YUDISLEYSANCHEZ@YAHOO.ES (CC: ) vía Outlook.
# Correo enviado con éxito a Vargasberley14@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a albeiroclavijojuan1@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lucianaywilly@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maribelmoreno1006@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maribelmoreno1006@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a salinasalbaluz5@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a wilderperez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a obduliamarino19@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a kevinmuriciomesabuitrago@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fcaceres72@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a gclealo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a kennedyvelasco97@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carrenoandres839@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nelcylizethduqueholguin@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fc281063@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yeisoncastellano.45@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a morenorubenantonio78@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a williamhurtado7777@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carmenzaherrera111@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a silvia.bohorquez@uotc.edu.co (CC: ) vía Outlook.
# Correo enviado con éxito a dannyortiz3093@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dannyortiz3093@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a kike.bypv1994@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a natalialeon135@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edrimo.2010@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a camilogaitan673@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a guszmanrinconrosamaria@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marianosilvamoreno@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a m3451a@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a NELDORIOS_80@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a juankarlos74858@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a elflo76@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a oscarjmaldonado@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a efrenadrigueznuta927@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a oscarmontealegre09@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a consorviasurb2023@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a torresleon2012@hotmail.es (CC: ) vía Outlook.
# Correo enviado con éxito a yaspen122582@gmial.com (CC: ) vía Outlook.
# Correo enviado con éxito a geinerpinzon@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sandriscorredor@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carlosandressanchez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jorgereinaldosoledad@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a recursoshumanosdiazygil@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a morenodionicio92@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a pablomendoza1985@hotmaill.com (CC: ) vía Outlook.
# Correo enviado con éxito a yorbisramirezcgstamara@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a noregistra@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a IVANUSUGA319@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a vanesahernandez1203@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a grismaldotorres28@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carlosgaitan_05@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a eeudesninovargas@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a construccasas26@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a tecncagro20@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fafanluis331@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sgsst.tarkus@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mativera941@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cristhianpj93@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LUBIBONILLA-77@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a claroyopal128@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a josediaz30agus@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marisolrf18@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a DIPATRI.97@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a fermaria1024@outlook.com (CC: ) vía Outlook.
# Correo enviado con éxito a ANDREACATAÑOLAGOS@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a yanyres23@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yuriavi@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a juancogua1029645745@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lorenaleguizamon1225@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lopezhernandezc36@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a davilayaneth09@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marisolrf18@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dorelisduran1978@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a olgaluciagaviria2020@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a salinasparadadianamarcela@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a andraleames1993@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sofi_nmh@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luzp32999@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a eliana_110787@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yanyres23@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dianap78@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ruedap143@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carolinacespedes2308@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nocorreo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maittebenitez16@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a magnelimarino@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a evelyndariana03@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a 3118227071flor@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luzp32999@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dianap78@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a johannainocencio@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andreacatanolargo@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a analuciagarciabellizia@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LUZMARINA_54@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a dulcemar-12@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@orocue-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a DANACARILLO691@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a blanca.ines@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ks6321604@gmai.com (CC: ) vía Outlook.
# Correo enviado con éxito a norelby1992@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a karolinapa18@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a taniamoya546@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ANDREACATAÑOLAGOS@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a analuciagarciabellizia@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a melisajimenez582@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a leidygisell1829@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a pantojaliz89@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a olganieto.fuentes@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a gabi260321@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a pongutayudy@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maryeparra81@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andraleames1993@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lufepaca76@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a roajina@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MARTHAHEREDIAMONROY@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a MARTHAHEREDIAMONROY@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a MARTHAHEREDIAMONROY@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a kellyjhoanagutierrez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lilianapatriciaavendanocastane@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lilianapatriciaavendanocastane@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lilianapatriciaavendanocastane@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mireyalombana25@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ngamezbarret@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a samuelolga25@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jeineracevedo203@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ROSABELGOMEZS@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a 19JUANCARLOSD@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a luzdarydiazfuentes@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sfaineryduranolivos25@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nuyaca26@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ngamezbarret@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mariaosalazar04@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a acpinto84@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a pidiachejuliocesar@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a franciscoescalona70@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dayanasocha80@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a karenmoralesdeavila@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MARISELAIBICA@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a luzvytuay294@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mayeoros3@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jessik.uc@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a eliecercamacho910@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mayerpuerta1992@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a angeltorre92a@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a valeriolizarazo@hotmail.es (CC: ) vía Outlook.
# Correo enviado con éxito a aponteochoaleidyjohana@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a FABITO987_@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a gelen2176@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a didiermendez56@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a guarinduenascristianalexis@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a deubyfranco88@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edixonlez412@ciam.com.co (CC: ) vía Outlook.
# Correo enviado con éxito a tibduizajeman@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a diazramirezjuandavid37@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andresavilafelix21@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a samuelsocha25@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a acostaalfonsoj29@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a s.jhosmith1294@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jennyvelasquez1995@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nelsonramirez07@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a duberbohorquez@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a roncancioeduardjose@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jesushernando24@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a favianmurillo1998@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a arleydavison0724@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jhonvega.malaver@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a karolrubio1704@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yanorycs950407@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sanandres.insa@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lorenareinosorodriguez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@pore-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a javimeche0@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a apsequipo10@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cristiandavidbarrerabarrera@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a figueredoestiven@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a luzcorredor23@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a brianperez3033@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a Diazbarrerajoseluis90@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andresreyes@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SANDRA.ROJAS7432@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a LUDIRUIZ1632@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a nleidymarina@gmsil.com (CC: ) vía Outlook.
# Correo enviado con éxito a luistd1231@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a cepedawilmer679@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a davidtorresmolano@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fabianav2327@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a guillermodiaz3030@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a BECERRAFREDY31@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a yensyangelinagranados@yahoo.es (CC: ) vía Outlook.
# Correo enviado con éxito a taliachacon332@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sebastiangalindo905@gmaill.com (CC: ) vía Outlook.
# Correo enviado con éxito a PULIOREYESDORELY@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a estebanestebangualdron@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a DAGERCONTABLE@GMAIL.COM (CC: ) vía Outlook.
# Error al enviar correo vía Outlook: (-2147352567, 'Ocurrió una excepción.', (4096, 'Microsoft Outlook', 'Outlook no reconoce alguno de los nombres. ', None, 0, -2147467259), None)
# Correo enviado con éxito a elio.parraheidy@outlook.com (CC: ) vía Outlook.
# Correo enviado con éxito a parravallejoandresjulian@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a erinsonsolano@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jhoysorduz@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a Losgavilanes12@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a MYLEMS@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a toco_1887@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a je391760@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yoly3182@hotmail.com (CC: ) vía Outlook.
# ...
# Correo enviado con éxito a jaimealbertosoto@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sgsst.tarkus@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ALEXISVIVES58@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a resursoshumanosdiazygil@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a karitoarevalo.0510@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a psicolucita@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a elsa23424120@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a carmenperezp05@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mariayadirabuitragoavila@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yensua1324@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a contador@lva.com.co (CC: ) vía Outlook.
# Correo enviado con éxito a CANYTVR@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a Tbarrera@hotmail.es (CC: ) vía Outlook.
# Correo enviado con éxito a zapataligia664@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanae.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a JGLS20@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a lidyalilianagalindoramirez@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a marinaluz0518@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a restreoyurani90@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a savin06@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@nunchia-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a LUZEL3858@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a smilenahernandez83@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a adrilozaon072@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a 270477mary@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a odiliachaparrorivas@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ediliabarrera89@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a RUBYCELLOROCUE@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a yoribec@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lucre102009@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a michelle22romero10@gamail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LUZELENA8006@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a MAYERLYMARTINEZ650@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a LUISBLANCO954@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a jaimerod@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a villabonamotor@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sarmientosandramabel@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dairalissedmanfara@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a archila-m@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SOLMAR_2209@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a danielfernandocalle23@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a romulobellangel@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a magnomendoza22@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a NELSONNEN_15@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a henrymojica58@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a julioberlnalgutierrez07@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a andres.cell@hotmail.com (CC: ) vía Outlook.
# Error al enviar correo vía Outlook: (-2147352567, 'Ocurrió una excepción.', (4096, 'Microsoft Outlook', 'Necesitamos saber a quién enviar esto. Asegúrate de introducir al menos un nombre.', None, 0, -2147467259), None)
# Correo enviado con éxito a walterostumaymayerly@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a williammorenoortiz17@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a pachecoboni22@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a pulidomauricio1972@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a JR7390400@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a manoloachagua670@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a klaus-perez@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ODCEPEDA74@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a gilacho-11@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a gustavorios@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a josecarvajalcol@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a trabajadorespmcp@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a T.HEAVEN@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a PABLOALFONSO@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a JOSE97@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a gabrielgalindo14@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a enertuay416@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a oscar.moranticos@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dagobertorojasruiz@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a stellaperillavaca@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a EDWARTORRESRAMIREZLA84@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a recursoshumanosdiazygil@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a JHONR5098@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a JHONR5098@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a freddybermudezhernandez60@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a rodrigodlegadocastro@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a rrhumanos@ecoflora.com.co (CC: ) vía Outlook.
# Correo enviado con éxito a adamenorely623@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SMYT-9210@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a velazquezjosealexander97@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a diegobarragan2228@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a yogny30arpa@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a zaganime1984@hotmail.com (CC: ) vía Outlook.
# Error al enviar correo vía Outlook: (-2147352567, 'Ocurrió una excepción.', (4096, 'Microsoft Outlook', 'Necesitamos saber a quién enviar esto. Asegúrate de introducir al menos un nombre.', None, 0, -2147467259), None)
# Correo enviado con éxito a erikasalguera@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a SERVIORINOCOYOPAL@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a ediliainocencio@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ALVEIRO73@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a davidtabaco2@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a josegonzale@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a olgarubyortizbet.ancourt@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a emiror@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a noralbagalindez16@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a julioortegon150@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a caterine.82tamara@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mabemalca24@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a alvaroestepa459@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a camachitokey91@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ireneshalejo12@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@tauramena-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a lancherose31@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a edilmadiaz1975@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a BOHORQUEZNATALIA76@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a nuvar08@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a laltuvikke@gufum.com (CC: ) vía Outlook.
# Correo enviado con éxito a berlithz2905@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a T.HEAVEN@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a LILIANATATYS03@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a l-ama94@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cuevasyuli089@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cuevasyuli089@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a l-ama94@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a cuevasyuli089@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ligialopezcobos@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jessikajaramillo311@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a lindaymarhisol1998@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@nunchia-casanare.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a maferj22@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a factipsvillanuevaacsi@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a csarosorio6@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a YOLIMAOROZCOPEREZ93@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a lancherose31@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a adamenorely623@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a jessikajaramillo311@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a kathht1420@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a LANCHEROCE@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a antonellavargasmartinez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a guevarazulma53@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maferj22@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a JGLS20@HOTMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a adamenorely623@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a mariayadirabuitragoavila@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a berlithz2905@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a antonellavargasmartinez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a restrepoyurani90@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a maferj22@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a YOLIMAOROZCOPEREZ93@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a nana2014106@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanae.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a bohorqueznatalia76@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a arikapaolavasquezbohorquez@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a sisben@yopal-casanae.gov.co (CC: ) vía Outlook.
# Correo enviado con éxito a danielduran1136@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a fabioanzueta1994@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a dimeyeler@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a javierdja@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a angelita94_03@hotmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a anavargas0796@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a saracorredoraguilar@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a miguelaguirre@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a barretolisarazokevinandres@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a ESTEVANMARTINEZC22@GMAIL.COM (CC: ) vía Outlook.
# Correo enviado con éxito a jeynnyjohanabohorquezafricano@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a manoklito@yahoo.es (CC: ) vía Outlook.
# Correo enviado con éxito a mailyjeraxy13@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a orlandogomez536@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a anavargas0796@gmail.com (CC: ) vía Outlook.
# Correo enviado con éxito a angelita94_03@hotmail.com (CC: ) vía Outlook.
# PDF generado para municipio AGUAZUL: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_AGUAZUL_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio CHÁMEZA: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_CHÁMEZA_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio HATO COROZAL: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_HATO COROZAL_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio LA SALINA: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_LA SALINA_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio MANÍ: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_MANÍ_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio MONTERREY: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_MONTERREY_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio NUNCHÍA: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_NUNCHÍA_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio OROCUÉ: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_OROCUÉ_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio PAZ DE ARIPORO: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_PAZ DE ARIPORO_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio PORE: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_PORE_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio RECETOR: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_RECETOR_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio SABANALARGA: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_SABANALARGA_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio SAN LUIS DE PALENQUE: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_SAN LUIS DE PALENQUE_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio SÁCAMA: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_SÁCAMA_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio TAURAMENA: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_TAURAMENA_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio TRINIDAD: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_TRINIDAD_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio TÁMARA: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_TÁMARA_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio VILLANUEVA: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_VILLANUEVA_Movilidad064_Septiembre_2025.pdf
# PDF generado para municipio YOPAL: \\Servernas\AYC2\(01. ASEGURAMIENTO)\01. ASEGURAMIENTO\01. REGIMEN SUBSIDIADO\MUNICIPIOS 2025\MOVILIDAD_064\09_SEPTIEMBRE\CORREOS USUARIOS\Correo_YOPAL_Movilidad064_Septiembre_2025.pdf
# Proceso completado.
